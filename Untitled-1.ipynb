# %%
import os
import random
import numpy as np
import pandas as pd

# reproducibility
RANDOM_SEED = 42
os.environ['PYTHONHASHSEED'] = str(RANDOM_SEED)
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_predict
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, roc_curve, confusion_matrix, classification_report)
import matplotlib.pyplot as plt
import seaborn as sns

# Models
from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# TensorFlow for NN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

DATA_PATH = "spotify_churn_dataset.csv"
TARGET_COL = "is_churned"

# %%
# Загрузка и быстрая разведка
df = pd.read_csv(DATA_PATH)
print("Rows, cols:", df.shape)
display(df.head())
display(df.info())
display(df.describe(include='all').T)
# Out:
# Rows, cols: (8000, 12)
#    user_id  gender  age country subscription_type  listening_time  \
# 0        1  Female   54      CA              Free              26
# 1        2   Other   33      DE            Family             141
# 2        3    Male   38      AU           Premium             199
# 3        4  Female   22      CA           Student              36
# 4        5   Other   29      US            Family             250
#
#    songs_played_per_day  skip_rate device_type  ads_listened_per_week  \
# 0                    23       0.20     Desktop                     31
# 1                    62       0.34         Web                      0
# 2                    38       0.04      Mobile                      0
# 3                     2       0.31      Mobile                      0
# 4                    57       0.36      Mobile                      0
#
#    offline_listening  is_churned
# 0                  0           1
# 1                  1           0
# 2                  1           1
# 3                  1           0
# 4                  1           1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   user_id                8000 non-null   int64
#  1   gender                 8000 non-null   object
#  2   age                    8000 non-null   int64
#  3   country                8000 non-null   object
#  4   subscription_type      8000 non-null   object
#  5   listening_time         8000 non-null   int64
#  6   songs_played_per_day   8000 non-null   int64
#  7   skip_rate              8000 non-null   float64
#  8   device_type            8000 non-null   object
#  9   ads_listened_per_week  8000 non-null   int64
#  10  offline_listening      8000 non-null   int64
#  11  is_churned             8000 non-null   int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 750.1+ KB
# None
#                         count unique      top  freq       mean         std  \
# user_id                8000.0    NaN      NaN   NaN     4000.5  2309.54541
# gender                   8000      3     Male  2691        NaN         NaN
# age                    8000.0    NaN      NaN   NaN  37.662125   12.740359
# country                  8000      8       AU  1034        NaN         NaN
# subscription_type        8000      4  Premium  2115        NaN         NaN
# listening_time         8000.0    NaN      NaN   NaN  154.06825   84.015596
# songs_played_per_day   8000.0    NaN      NaN   NaN   50.12725   28.449762
# skip_rate              8000.0    NaN      NaN   NaN   0.300127    0.173594
# device_type              8000      3  Desktop  2778        NaN         NaN
# ads_listened_per_week  8000.0    NaN      NaN   NaN   6.943875   13.617953
# offline_listening      8000.0    NaN      NaN   NaN    0.74775    0.434331
# is_churned             8000.0    NaN      NaN   NaN   0.258875    0.438044
#
#                         min      25%     50%      75%     max
# user_id                 1.0  2000.75  4000.5  6000.25  8000.0
# gender                  NaN      NaN     NaN      NaN     NaN
# age                    16.0     26.0    38.0     49.0    59.0
# country                 NaN      NaN     NaN      NaN     NaN
# subscription_type       NaN      NaN     NaN      NaN     NaN
# listening_time         10.0     81.0   154.0    227.0   299.0
# songs_played_per_day    1.0     25.0    50.0     75.0    99.0
# skip_rate               0.0     0.15     0.3     0.45     0.6
# device_type             NaN      NaN     NaN      NaN     NaN
# ads_listened_per_week   0.0      0.0     0.0      5.0    49.0
# offline_listening       0.0      0.0     1.0      1.0     1.0
# is_churned              0.0      0.0     0.0      1.0     1.0

# %%
# Простая проверка пропусков и типов
missing = df.isna().sum().sort_values(ascending=False)
print("Top missing:\n", missing[missing>0].head(20))
# Out:
# Top missing:
#  Series([], dtype: int64)

# %%
# Предположим: целевой столбец бинарный
if df[TARGET_COL].dtype == object:
    df[TARGET_COL] = df[TARGET_COL].map(lambda x: 1 if str(x).lower() in ['yes','true','1','y','churn','t'] else 0)

# Если категориальные признаки — кодируем:
cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
# исключаем целевой, если он строчный
if TARGET_COL in cat_cols:
    cat_cols.remove(TARGET_COL)

print("categorical columns:", cat_cols)
# Out:
# categorical columns: ['gender', 'country', 'subscription_type', 'device_type']

# %%
# Разделяем признаки и цель
# Удаляем ненужные колонки
df = df.drop(columns=['user_id'])
X = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL].astype(int)

# Для простоты: numeric_cols / cat_cols
numeric_cols = X.select_dtypes(include=[np.number]).columns.tolist()
# уже получили cat_cols ранее; если какие-то числовые признаки выглядят как id, можно удалить:
print("numeric:", len(numeric_cols), "categorical:", len(cat_cols))
# Out:
# numeric: 6 categorical: 4

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(transformers=[
    ('num', Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', MinMaxScaler())  # не даёт отрицательных значений
    ]), numeric_cols),
    ('cat', Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('ohe', OneHotEncoder(handle_unknown='ignore'))
    ]), cat_cols)
])

# %%
# Разделение данных
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=RANDOM_SEED
)

# Применяем препроцессор к train
X_train_proc = preprocessor.fit_transform(X_train)
X_test_proc = preprocessor.transform(X_test)

# Подсчёт весов классов
from sklearn.utils.class_weight import compute_class_weight
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights = dict(zip(np.unique(y_train), class_weights))

# Балансировка уже преобразованных данных
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=RANDOM_SEED)
X_train_bal, y_train_bal = smote.fit_resample(X_train_proc, y_train)

# Теперь обучающие данные — сбалансированные и числовые
X_train_proc, y_train = X_train_bal, y_train_bal

# %%
# Утилита: обучение модели, предсказания, вычисление метрик и ROC
def evaluate_model(model, X_train_proc, X_test_proc, y_train, y_test):
    model.fit(X_train_proc, y_train)
    y_pred = model.predict(X_test_proc)
    
    if hasattr(model, "predict_proba"):
        y_score = model.predict_proba(X_test_proc)[:, 1]
    else:
        try:
            y_score = model.decision_function(X_test_proc)
        except:
            y_score = y_pred

    metrics = {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred, zero_division=0),
        'recall': recall_score(y_test, y_pred, zero_division=0),
        'f1': f1_score(y_test, y_pred, zero_division=0),
        'auc': roc_auc_score(y_test, y_score)
    }
    return model, y_pred, y_score, metrics

# %%
# Список моделей
models = {
    'GaussianNB': GaussianNB(),
    'MultinomialNB': MultinomialNB(),
    'ComplementNB': ComplementNB(),
    'BernoulliNB': BernoulliNB(),
    'DecisionTree': DecisionTreeClassifier(class_weight='balanced', random_state=RANDOM_SEED),
    'LDA': LinearDiscriminantAnalysis(),
    'SVM': SVC(class_weight='balanced', probability=True, random_state=RANDOM_SEED),
    'KNN': KNeighborsClassifier()
}

# %%
# Быстрая baseline оценка
results = {}
pipes = {}
for name, model in models.items():
    try:
        mdl, y_pred, y_score, metrics = evaluate_model(model, X_train_proc, X_test_proc, y_train, y_test)
        results[name] = metrics
        print(f"{name}: {metrics}")
    except Exception as e:
        print(f"{name} failed: {e}")
# Out:
# GaussianNB: {'accuracy': 0.54125, 'precision': 0.26331360946745563, 'recall': 0.42995169082125606, 'f1': 0.326605504587156, 'auc': 0.5007026419336706}
# MultinomialNB: {'accuracy': 0.5175, 'precision': 0.2587601078167116, 'recall': 0.463768115942029, 'f1': 0.33217993079584773, 'auc': 0.5087514561999495}
# ComplementNB: {'accuracy': 0.5175, 'precision': 0.2587601078167116, 'recall': 0.463768115942029, 'f1': 0.33217993079584773, 'auc': 0.5087514561999495}
# BernoulliNB: {'accuracy': 0.50875, 'precision': 0.26153846153846155, 'recall': 0.4927536231884058, 'f1': 0.3417085427135678, 'auc': 0.5076302840710055}
# DecisionTree: {'accuracy': 0.555625, 'precision': 0.23992994746059546, 'recall': 0.3309178743961353, 'f1': 0.2781725888324873, 'auc': 0.482490977670243}
# LDA: {'accuracy': 0.513125, 'precision': 0.26018396846254926, 'recall': 0.4782608695652174, 'f1': 0.33702127659574466, 'auc': 0.49794502692442427}
# SVM: {'accuracy': 0.555625, 'precision': 0.2753403933434191, 'recall': 0.4396135265700483, 'f1': 0.3386046511627907, 'auc': 0.5229835194825296}
# KNN: {'accuracy': 0.550625, 'precision': 0.28730822873082285, 'recall': 0.4975845410628019, 'f1': 0.36427939876215737, 'auc': 0.5515790095396371}

# %%
# Табличка результатов
res_df = pd.DataFrame(results).T
display(res_df.sort_values(by='f1', ascending=False))
# Out:
#                accuracy  precision    recall        f1       auc
# KNN            0.550625   0.287308  0.497585  0.364279  0.551579
# BernoulliNB    0.508750   0.261538  0.492754  0.341709  0.507630
# SVM            0.555625   0.275340  0.439614  0.338605  0.522984
# LDA            0.513125   0.260184  0.478261  0.337021  0.497945
# MultinomialNB  0.517500   0.258760  0.463768  0.332180  0.508751
# ComplementNB   0.517500   0.258760  0.463768  0.332180  0.508751
# GaussianNB     0.541250   0.263314  0.429952  0.326606  0.500703
# DecisionTree   0.555625   0.239930  0.330918  0.278173  0.482491

# %%
# ROC-кривые всех моделей
plt.figure(figsize=(8,6))
for name, pipe in pipes.items():
    try:
        y_score = pipe.predict_proba(X_test)[:,1]
    except:
        try:
            y_score = pipe.decision_function(X_test)
        except:
            continue
    fpr, tpr, _ = roc_curve(y_test, y_score)
    plt.plot(fpr, tpr, label=f"{name} (AUC={roc_auc_score(y_test,y_score):.3f})")
plt.plot([0,1],[0,1],'k--', alpha=0.4)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves")
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_SEED)

param_grids = {
    'DecisionTree': {
        'clf__max_depth': [3, 5, 10, None],
        'clf__min_samples_split': [2, 5, 10],
        'clf__criterion': ['gini', 'entropy']
    },
    'SVM': {
        'clf__C': [0.1, 1, 10],
        'clf__kernel': ['rbf', 'linear'],
        'clf__gamma': ['scale', 'auto']
    },
    'KNN': {
        'clf__n_neighbors': [3,5,7,9],
        'clf__weights': ['uniform','distance']
    },
    'GaussianNB': {
        # у GaussianNB нет гиперпараметров
    },
    'MultinomialNB': {
        'clf__alpha': [0.01, 0.1, 1.0]
    },
    'BernoulliNB': {
        'clf__alpha': [0.01, 0.1, 1.0]
    },
    'ComplementNB': {
        'clf__alpha': [0.01, 0.1, 1.0]
    },
    'LDA': {
        'clf__solver': ['svd']
    }
}

# %%
# Выполним GridSearch для нескольких моделей
best_models = {}
for name in ['DecisionTree','SVM','KNN','MultinomialNB','BernoulliNB','ComplementNB','LDA']:
    model = models[name]
    grid = param_grids.get(name, {})
    pipe = Pipeline(steps=[('preproc', preprocessor), ('clf', model)])
    if grid:
        gs = GridSearchCV(pipe, param_grid=grid, scoring='f1', cv=cv, n_jobs=-1, verbose=1)
        gs.fit(X_train, y_train)
        print(f"{name} best params: {gs.best_params_}, best f1: {gs.best_score_:.4f}")
        best_models[name] = gs.best_estimator_
    else:
        pipe.fit(X_train, y_train)
        best_models[name] = pipe
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# DecisionTree best params: {'clf__criterion': 'entropy', 'clf__max_depth': None, 'clf__min_samples_split': 2}, best f1: 0.2825
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# SVM best params: {'clf__C': 10, 'clf__gamma': 'scale', 'clf__kernel': 'rbf'}, best f1: 0.0386
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# KNN best params: {'clf__n_neighbors': 3, 'clf__weights': 'distance'}, best f1: 0.2103
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# MultinomialNB best params: {'clf__alpha': 0.01}, best f1: 0.0000
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# BernoulliNB best params: {'clf__alpha': 0.01}, best f1: 0.0000
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# ComplementNB best params: {'clf__alpha': 0.1}, best f1: 0.3443
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# LDA best params: {'clf__solver': 'svd'}, best f1: 0.0000

# %%
# Оценка лучших моделей
final_results = {}
for name, pipe in best_models.items():
    y_pred = pipe.predict(X_test)
    try:
        y_score = pipe.predict_proba(X_test)[:,1]
    except:
        try:
            y_score = pipe.decision_function(X_test)
        except:
            y_score = y_pred
    metrics = {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred, zero_division=0),
        'recall': recall_score(y_test, y_pred, zero_division=0),
        'f1': f1_score(y_test, y_pred, zero_division=0),
        'auc': roc_auc_score(y_test, y_score)
    }
    final_results[name] = metrics
pd.DataFrame(final_results).T.sort_values(by='f1', ascending=False)
# Out:
#                accuracy  precision    recall        f1       auc
# ComplementNB   0.537500   0.274862  0.480676  0.349736  0.503682
# KNN            0.671875   0.315615  0.229469  0.265734  0.543637
# DecisionTree   0.608125   0.247031  0.251208  0.249102  0.491961
# SVM            0.736250   0.277778  0.012077  0.023148  0.477161
# MultinomialNB  0.741250   0.000000  0.000000  0.000000  0.503674
# BernoulliNB    0.741250   0.000000  0.000000  0.000000  0.506515
# LDA            0.741250   0.000000  0.000000  0.000000  0.497872

# %%
# Визуализация метрик (столбчатая диаграмма)
res_df2 = pd.DataFrame(final_results).T.reset_index().melt(id_vars='index', var_name='metric', value_name='value')
plt.figure(figsize=(10,5))
sns.barplot(data=res_df2, x='index', y='value', hue='metric')
plt.xticks(rotation=45)
plt.title("Сравнение метрик для моделей")
plt.legend(loc='best')
plt.show()

# %%
import tempfile
import datetime
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
import os

# Преобразуем данные (ещё раз, на всякий случай)
X_train_proc = preprocessor.fit_transform(X_train)
X_test_proc = preprocessor.transform(X_test)

# Определяем входную размерность
input_shape = X_train_proc.shape[1]
tf.random.set_seed(RANDOM_SEED)

# Функция построения модели
def build_model(hidden_units=[64, 32], lr=1e-3, dropout=0.2):
    model = keras.Sequential()
    model.add(layers.Input(shape=(input_shape,)))
    for units in hidden_units:
        model.add(layers.Dense(units, activation='relu'))
        if dropout > 0:
            model.add(layers.Dropout(dropout))
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss='binary_crossentropy',
        metrics=['accuracy', keras.metrics.Precision(), keras.metrics.Recall(), keras.metrics.AUC(name='auc')]
    )
    return model


# Создание модели
model = build_model(hidden_units=[128, 64], lr=1e-3, dropout=0.3)
model.summary()


# Уникальная папка для TensorBoard
log_dir = os.path.join(tempfile.gettempdir(), "tf_logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

# Создаём родительскую папку
os.makedirs(log_dir, exist_ok=True)

tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

history = model.fit(
    X_train_proc, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    class_weight=class_weights,
    callbacks=[tensorboard_callback, early_stop],
    verbose=1
)


# === Оценка на тестовой выборке ===
y_pred_proba = model.predict(X_test_proc)
y_pred = (y_pred_proba > 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("AUC:", roc_auc_score(y_test, y_pred_proba))
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_27 (Dense)                │ (None, 128)            │         3,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,521 (45.00 KB)
#  Trainable params: 11,521 (45.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5023 - auc: 0.4928 - loss: 0.7033 - precision_4: 0.2521 - recall_4: 0.4651 - val_accuracy: 0.3250 - val_auc: 0.5194 - val_loss: 0.7143 - val_precision_4: 0.2546 - val_recall_4: 0.8558
# Epoch 2/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5115 - auc: 0.5171 - loss: 0.6962 - precision_4: 0.2682 - recall_4: 0.5086 - val_accuracy: 0.4578 - val_auc: 0.5130 - val_loss: 0.6996 - val_precision_4: 0.2665 - val_recall_4: 0.6442
# Epoch 3/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4902 - auc: 0.5083 - loss: 0.6957 - precision_4: 0.2579 - recall_4: 0.5116 - val_accuracy: 0.4664 - val_auc: 0.5115 - val_loss: 0.6998 - val_precision_4: 0.2691 - val_recall_4: 0.6380
# Epoch 4/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5273 - auc: 0.5372 - loss: 0.6923 - precision_4: 0.2823 - recall_4: 0.5304 - val_accuracy: 0.5469 - val_auc: 0.5099 - val_loss: 0.6880 - val_precision_4: 0.2631 - val_recall_4: 0.4325
# Epoch 5/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5367 - auc: 0.5498 - loss: 0.6903 - precision_4: 0.2907 - recall_4: 0.5432 - val_accuracy: 0.5289 - val_auc: 0.4959 - val_loss: 0.6898 - val_precision_4: 0.2505 - val_recall_4: 0.4264
# Epoch 6/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5299 - auc: 0.5351 - loss: 0.6920 - precision_4: 0.2827 - recall_4: 0.5259 - val_accuracy: 0.4898 - val_auc: 0.4998 - val_loss: 0.6948 - val_precision_4: 0.2526 - val_recall_4: 0.5123
# Epoch 7/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5271 - auc: 0.5458 - loss: 0.6910 - precision_4: 0.2874 - recall_4: 0.5537 - val_accuracy: 0.4711 - val_auc: 0.5065 - val_loss: 0.6985 - val_precision_4: 0.2586 - val_recall_4: 0.5767
# Epoch 8/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5459 - auc: 0.5577 - loss: 0.6888 - precision_4: 0.2943 - recall_4: 0.5342 - val_accuracy: 0.5023 - val_auc: 0.4967 - val_loss: 0.6945 - val_precision_4: 0.2528 - val_recall_4: 0.4877
# Epoch 9/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5402 - auc: 0.5601 - loss: 0.6879 - precision_4: 0.2942 - recall_4: 0.5492 - val_accuracy: 0.5156 - val_auc: 0.4948 - val_loss: 0.6906 - val_precision_4: 0.2483 - val_recall_4: 0.4448
# Epoch 10/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5447 - auc: 0.5693 - loss: 0.6861 - precision_4: 0.2956 - recall_4: 0.5432 - val_accuracy: 0.4461 - val_auc: 0.4961 - val_loss: 0.7053 - val_precision_4: 0.2523 - val_recall_4: 0.5982
# Epoch 11/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5393 - auc: 0.5684 - loss: 0.6863 - precision_4: 0.2987 - recall_4: 0.5733 - val_accuracy: 0.5305 - val_auc: 0.5084 - val_loss: 0.6888 - val_precision_4: 0.2705 - val_recall_4: 0.4969
# Epoch 12/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5525 - auc: 0.5715 - loss: 0.6857 - precision_4: 0.3054 - recall_4: 0.5657 - val_accuracy: 0.5195 - val_auc: 0.4931 - val_loss: 0.6910 - val_precision_4: 0.2604 - val_recall_4: 0.4816
# Epoch 13/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5654 - auc: 0.5900 - loss: 0.6824 - precision_4: 0.3123 - recall_4: 0.5590 - val_accuracy: 0.4875 - val_auc: 0.4950 - val_loss: 0.6988 - val_precision_4: 0.2602 - val_recall_4: 0.5491
# Epoch 14/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5482 - auc: 0.5840 - loss: 0.6825 - precision_4: 0.3034 - recall_4: 0.5695 - val_accuracy: 0.5312 - val_auc: 0.4990 - val_loss: 0.6897 - val_precision_4: 0.2596 - val_recall_4: 0.4540
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.59      0.66      1186
#            1       0.28      0.45      0.34       414
#
#     accuracy                           0.55      1600
#    macro avg       0.52      0.52      0.50      1600
# weighted avg       0.63      0.55      0.58      1600
#
# AUC: 0.512938794795969

# %%
# Оценка на тесте
test_results = model.evaluate(X_test_proc, y_test, verbose=0)
loss, acc, precision, recall, auc = test_results
print(f"NN test acc: {acc:.4f}, precision: {precision:.4f}, recall: {recall:.4f}, auc: {auc:.4f}, loss: {loss:.4f}")

# Предсказания для ROC
y_pred_nn = (model.predict(X_test_proc).ravel() > 0.5).astype(int)
y_score_nn = model.predict(X_test_proc).ravel()

nn_metrics = {
    'accuracy': accuracy_score(y_test, y_pred_nn),
    'precision': precision_score(y_test, y_pred_nn, zero_division=0),
    'recall': recall_score(y_test, y_pred_nn, zero_division=0),
    'f1': f1_score(y_test, y_pred_nn, zero_division=0),
    'auc': roc_auc_score(y_test, y_score_nn)
}

print("NN metrics:", nn_metrics)
final_results['NeuralNet'] = nn_metrics
# Out:
# NN test acc: 0.5537, precision: 0.2774, recall: 0.4517, auc: 0.5129, loss: 0.6881
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step
# NN metrics: {'accuracy': 0.55375, 'precision': 0.2774480712166172, 'recall': 0.45169082125603865, 'f1': 0.34375, 'auc': 0.512938794795969}

# %%
# ROC для NN + классика
plt.figure(figsize=(8,6))
# NN
fpr, tpr, _ = roc_curve(y_test, y_score_nn)
plt.plot(fpr, tpr, label=f"NeuralNet (AUC={nn_metrics['auc']:.3f})")
# классические
for name, pipe in best_models.items():
    try:
        y_score = pipe.predict_proba(X_test)[:,1]
    except:
        try:
            y_score = pipe.decision_function(X_test)
        except:
            continue
    plt.plot(*roc_curve(y_test, y_score)[:2], label=f"{name} (AUC={roc_auc_score(y_test, y_score):.3f})")
plt.plot([0,1],[0,1],'k--', alpha=0.3)
plt.xlabel('FPR'); plt.ylabel('TPR'); plt.title('ROC: NN vs Classical')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
